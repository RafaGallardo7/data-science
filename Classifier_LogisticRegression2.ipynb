# %% [markdown]
# <a href="https://colab.research.google.com/github/RafaGallardo7/data-science/blob/main/Classifier_LogisticRegression2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## https://machinelearningmastery.com/standard-machine-learning-datasets/
# ## 5. Banknote Dataset

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
# the data set is available at the url below.
URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt"

# using the read_csv function in the pandas library, we load the data into a dataframe.

df = pd.read_csv(URL)

#df.shape

# add Column name to rows
df.columns = ['Variance', 'Skewness', 'Kurtosis', 'Entropy', 'Class']

# show 5 random rows from the dataset
df.sample(5)
# Out:
#       Variance  Skewness  Kurtosis  Entropy  Class
# 1058  -3.23050   -7.2135   11.6433 -0.94613      1
# 816   -2.58800    3.8654   -0.3336 -1.27970      1
# 388    3.79820   10.4230   -4.1602 -4.97280      0
# 870   -0.75793    2.5349   -3.0464 -1.26290      1
# 221    1.09870    0.6394    5.9890 -0.58277      0

# %%
df.shape
# Out:
# (1371, 5)

# %%
target = df["Class"]
features = df[["Variance","Skewness","Skewness","Entropy"]]

# %%
classifier = LogisticRegression()
classifier.fit(features,target)
# Out:
# LogisticRegression()

# %%
#Higher the score, better the model.
classifier.score(features,target)
# Out:
# 0.8781911013858498

# %%
classifier.predict([[3.2692,3.4184,0.20706,-0.066824]])
# Out:
# array([0])
